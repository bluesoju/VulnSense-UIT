# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cp -R /content/drive/MyDrive/NCKH_Trinh_Kien_Hoang/Kien/CFG_SCKGNN_Detect/binary_extractor /content

# %%
# !sudo update-alternatives --install /usr/bin/python3 python3 /usr/bin/python3.8 1

# %%
# !sudo update-alternatives --config python3
# Out:
# There are 2 choices for the alternative python3 (providing /usr/bin/python3).
#
#   Selection    Path                 Priority   Status
# ------------------------------------------------------------
# * 0            /usr/bin/python3.10   2         auto mode
#   1            /usr/bin/python3.10   2         manual mode
#   2            /usr/bin/python3.8    1         manual mode
#
# Press <enter> to keep the current choice[*], or type selection number: 2
# update-alternatives: using /usr/bin/python3.8 to provide /usr/bin/python3 (python3) in manual mode

# %%
# !apt-get install python3-pip
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   python-pip-whl python3-setuptools python3-wheel
# Suggested packages:
#   python-setuptools-doc
# The following NEW packages will be installed:
#   python-pip-whl python3-pip python3-setuptools python3-wheel
# 0 upgraded, 4 newly installed, 0 to remove and 46 not upgraded.
# Need to get 2,389 kB of archives.
# After this operation, 4,933 kB of additional disk space will be used.
# Get:1 http://security.ubuntu.com/ubuntu focal-security/universe amd64 python-pip-whl all 20.0.2-5ubuntu1.9 [1,805 kB]
# Get:2 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 python3-setuptools all 45.2.0-1ubuntu0.1 [330 kB]
# Get:3 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 python3-wheel all 0.34.2-1ubuntu0.1 [23.9 kB]
# Get:4 http://security.ubuntu.com/ubuntu focal-security/universe amd64 python3-pip all 20.0.2-5ubuntu1.9 [231 kB]
# Fetched 2,389 kB in 2s (1,017 kB/s)
# Selecting previously unselected package python-pip-whl.
# (Reading database ... 122541 files and directories currently installed.)
# Preparing to unpack .../python-pip-whl_20.0.2-5ubuntu1.9_all.deb ...
# Unpacking python-pip-whl (20.0.2-5ubuntu1.9) ...
# Selecting previously unselected package python3-setuptools.
# Preparing to unpack .../python3-setuptools_45.2.0-1ubuntu0.1_all.deb ...
# Unpacking python3-setuptools (45.2.0-1ubuntu0.1) ...
# Selecting previously unselected package python3-wheel.
# Preparing to unpack .../python3-wheel_0.34.2-1ubuntu0.1_all.deb ...
# Unpacking python3-wheel (0.34.2-1ubuntu0.1) ...
# Selecting previously unselected package python3-pip.
# Preparing to unpack .../python3-pip_20.0.2-5ubuntu1.9_all.deb ...
# Unpacking python3-pip (20.0.2-5ubuntu1.9) ...
# Setting up python3-setuptools (45.2.0-1ubuntu0.1) ...
# Setting up python3-wheel (0.34.2-1ubuntu0.1) ...
# Setting up python-pip-whl (20.0.2-5ubuntu1.9) ...
# Setting up python3-pip (20.0.2-5ubuntu1.9) ...
# Processing triggers for man-db (2.9.1-1) ...

# %%
# !pip -V
# Out:
# pip 20.0.2 from /usr/lib/python3/dist-packages/pip (python 3.8)

# %%
# !apt-get install graphviz
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# graphviz is already the newest version (2.42.2-3build2).
# 0 upgraded, 0 newly installed, 0 to remove and 46 not upgraded.

# %%
# !pip install wasm
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting wasm
#   Downloading wasm-1.2-py3-none-any.whl (15 kB)
# Requirement already satisfied: setuptools in /usr/lib/python3/dist-packages (from wasm) (45.2.0)
# Installing collected packages: wasm
# Successfully installed wasm-1.2

# %%
# !pip install z3-solver
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting z3-solver
#   Downloading z3_solver-4.12.2.0-py2.py3-none-manylinux2014_x86_64.whl (55.7 MB)
#      |████████████████████████████████| 55.7 MB 1.2 MB/s
# Installing collected packages: z3-solver
# Successfully installed z3-solver-4.12.2.0

# %%
# !pip install graphviz
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting graphviz
#   Downloading graphviz-0.20.1-py3-none-any.whl (47 kB)
#      |████████████████████████████████| 47 kB 2.1 MB/s
# Installing collected packages: graphviz
# Successfully installed graphviz-0.20.1

# %%
# !cp -R /content/drive/MyDrive/NCKH_Trinh_Kien_Hoang/Kien/CFG_SCKGNN_Detect/binary_cfg_extractor.py /content

# %%
# !python3 binary_cfg_extractor.py
# Out:
# 0x334a934fa07fce4fb7b1c89457fe9754c08f4d41.sol.txt
# 0x334a934fa07fce4fb7b1c89457fe9754c08f4d41.sol.txt is done!
# 0x334a934fa07fce4fb7b1c89457fe9754c08f4d41.sol
# 0x5d0fdc4f46af16d28324788a2ff4e86b1667d578.sol.txt
# WARNING:binary_extractor.arch.evm.cfg:function signatures collision: ['decimals()', 'available_assert_time(uint16,uint64)']
# WARNING:binary_extractor.arch.evm.cfg:function signatures collision: ['collate_propagate_storage(bytes16)', 'burn(uint256)']
# WARNING:binary_extractor.arch.evm.cfg:function signatures collision: ['symbol()', 'link_classic_internal(uint64,int64)']
# WARNING:binary_extractor.arch.evm.emulator:[X] Loop detected, skipping JUMPI 0xcf3
# WARNING:binary_extractor.arch.evm.emulator:[X] push_instr.ssa %3A1 = #0xCF3
# WARNING:binary_extractor.arch.evm.emulator:[X] Loop detected, skipping JUMPI 0x6e7
# WARNING:binary_extractor.arch.evm.emulator:[X] push_instr.ssa %834 = #0x6E7
# 0x5d0fdc4f46af16d28324788a2ff4e86b1667d578.sol.txt is done!
# 0x5d0fdc4f46af16d28324788a2ff4e86b1667d578.sol
# 0x4eac873159b03884b92e50b366b6800da8d7eb68.sol.txt
# 0x4eac873159b03884b92e50b366b6800da8d7eb68.sol.txt is done!
# 0x4eac873159b03884b92e50b366b6800da8d7eb68.sol
# 0xbb2ac7e354c2b95ffa58ede51832a443129bb51f.sol.txt
# 0xbb2ac7e354c2b95ffa58ede51832a443129bb51f.sol.txt is done!
# 0xbb2ac7e354c2b95ffa58ede51832a443129bb51f.sol
# 0x5b6f03513fef300f8b3d804ea4040abdee1f3aa2.sol.txt
# WARNING:binary_extractor.arch.evm.cfg:function signatures collision: ['ideal_warn_timed(uint256,uint128)', 'owner()']
# 0x5b6f03513fef300f8b3d804ea4040abdee1f3aa2.sol.txt is done!
# 0x5b6f03513fef300f8b3d804ea4040abdee1f3aa2.sol
# 0x5fbf6a7c55f00f43fe73b7329fa46baa25f4cf14.sol.txt
# 0x5fbf6a7c55f00f43fe73b7329fa46baa25f4cf14.sol.txt is done!
# 0x5fbf6a7c55f00f43fe73b7329fa46baa25f4cf14.sol
# 0x18b9a456d4d3a81e1d9d0ae32044974ab3550da0.sol.txt
# WARNING:binary_extractor.arch.evm.cfg:function signatures collision: ['decimals()', 'available_assert_time(uint16,uint64)']
# WARNING:binary_extractor.arch.evm.cfg:function signatures collision: ['ideal_warn_timed(uint256,uint128)', 'owner()']
# WARNING:binary_extractor.arch.evm.cfg:function signatures collision: ['symbol()', 'link_classic_internal(uint64,int64)']
# WARNING:binary_extractor.arch.evm.emulator:[X] Loop detected, skipping JUMPI 0x124b
# WARNING:binary_extractor.arch.evm.emulator:[X] push_instr.ssa %2FB = #0x124B
# WARNING:binary_extractor.arch.evm.emulator:[X] Loop detected, skipping JUMPI 0x737
# WARNING:binary_extractor.arch.evm.emulator:[X] push_instr.ssa %7D0 = #0x737
# 0x18b9a456d4d3a81e1d9d0ae32044974ab3550da0.sol.txt is done!
# 0x18b9a456d4d3a81e1d9d0ae32044974ab3550da0.sol
# 0x6e8138188a413ab4eb6528d356e6c98ed0f1ce71.sol.txt
# 0x6e8138188a413ab4eb6528d356e6c98ed0f1ce71.sol.txt is done!
# 0x6e8138188a413ab4eb6528d356e6c98ed0f1ce71.sol
# 0xf1fd447dac5abeaba356cd0010bac95daa37c265.sol.txt
# WARNING:binary_extractor.arch.evm.emulator:[X] Loop detected, skipping JUMPI 0x26ad
# WARNING:binary_extractor.arch.evm.emulator:[X] push_instr.ssa %DC = #0x26AD
# WARNING:binary_extractor.arch.evm.emulator:[X] Loop detected, skipping JUMPI 0x256e
# WARNING:binary_extractor.arch.evm.emulator:[X] push_instr.ssa %1BC = #0x256E
# WARNING:binary_extractor.arch.evm.emulator:[X] Loop detected, skipping JUMPI 0x24ba
# WARNING:binary_extractor.arch.evm.emulator:[X] push_instr.ssa %263 = #0x24BA
# WARNING:binary_extractor.arch.evm.emulator:[X] Loop detected, skipping JUMPI 0x22f0
# WARNING:binary_extractor.arch.evm.emulator:[X] push_instr.ssa %37C = #0x22F0
# WARNING:binary_extractor.arch.evm.emulator:[X] Loop detected, skipping JUMPI 0x223c
# WARNING:binary_extractor.arch.evm.emulator:[X] push_instr.ssa %423 = #0x223C
# WARNING:binary_extractor.arch.evm.emulator:[X] Loop detected, skipping JUMPI 0x2188
# WARNING:binary_extractor.arch.evm.emulator:[X] push_instr.ssa %4CA = #0x2188
# WARNING:binary_extractor.arch.evm.emulator:[X] Loop detected, skipping JUMPI 0x20d4
# WARNING:binary_extractor.arch.evm.emulator:[X] push_instr.ssa %571 = #0x20D4
# WARNING:binary_extractor.arch.evm.emulator:[X] Loop detected, skipping JUMPI 0x1ea2
# WARNING:binary_extractor.arch.evm.emulator:[X] push_instr.ssa %6D3 = #0x1EA2
# WARNING:binary_extractor.arch.evm.emulator:[X] Loop detected, skipping JUMPI 0x1dee
# WARNING:binary_extractor.arch.evm.emulator:[X] push_instr.ssa %77A = #0x1DEE
# WARNING:binary_extractor.arch.evm.emulator:[X] Loop detected, skipping JUMPI 0x1caf
# WARNING:binary_extractor.arch.evm.emulator:[X] push_instr.ssa %85A = #0x1CAF
# WARNING:binary_extractor.arch.evm.emulator:[X] Loop detected, skipping JUMPI 0x1bfb
# WARNING:binary_extractor.arch.evm.emulator:[X] push_instr.ssa %901 = #0x1BFB
# WARNING:binary_extractor.arch.evm.emulator:[X] Loop detected, skipping JUMPI 0x1abc
# WARNING:binary_extractor.arch.evm.emulator:[X] push_instr.ssa %9E1 = #0x1ABC
# WARNING:binary_extractor.arch.evm.emulator:[X] Loop detected, skipping JUMPI 0x1a08
# WARNING:binary_extractor.arch.evm.emulator:[X] push_instr.ssa %A88 = #0x1A08
# WARNING:binary_extractor.arch.evm.emulator:[X] Loop detected, skipping JUMPI 0x1861
# WARNING:binary_extractor.arch.evm.emulator:[X] push_instr.ssa %BB1 = #0x1861
# WARNING:binary_extractor.arch.evm.emulator:[X] Loop detected, skipping JUMPI 0x17ad
# WARNING:binary_extractor.arch.evm.emulator:[X] push_instr.ssa %C58 = #0x17AD
# WARNING:binary_extractor.arch.evm.emulator:[X] Loop detected, skipping JUMPI 0x16f9
# WARNING:binary_extractor.arch.evm.emulator:[X] push_instr.ssa %CFF = #0x16F9
# WARNING:binary_extractor.arch.evm.emulator:[X] Loop detected, skipping JUMPI 0x15dd
# WARNING:binary_extractor.arch.evm.emulator:[X] push_instr.ssa %DEF = #0x15DD
# WARNING:binary_extractor.arch.evm.emulator:[X] Loop detected, skipping JUMPI 0x103d
# WARNING:binary_extractor.arch.evm.emulator:[X] push_instr.ssa %101C = #0x103D
# WARNING:binary_extractor.arch.evm.emulator:[X] Loop detected, skipping JUMPI 0xf89
# WARNING:binary_extractor.arch.evm.emulator:[X] push_instr.ssa %10C3 = #0xF89
# WARNING:binary_extractor.arch.evm.emulator:[X] Loop detected, skipping JUMPI 0xe4a
# WARNING:binary_extractor.arch.evm.emulator:[X] push_instr.ssa %11A3 = #0xE4A
# 0xf1fd447dac5abeaba356cd0010bac95daa37c265.sol.txt is done!
# 0xf1fd447dac5abeaba356cd0010bac95daa37c265.sol
# 0xb7a263d56605648ad054d4dc1aea24f244d7ba96.sol.txt
# 0xb7a263d56605648ad054d4dc1aea24f244d7ba96.sol.txt is done!
# 0xb7a263d56605648ad054d4dc1aea24f244d7ba96.sol
# 0xb60524d00de642355eb7992184788fa151e862f8.sol.txt
# 0xb60524d00de642355eb7992184788fa151e862f8.sol.txt is done!
# 0xb60524d00de642355eb7992184788fa151e862f8.sol
# 0x12b2b2331a72d375c453c160b2c8a7010eea510a.sol.txt
# 0x12b2b2331a72d375c453c160b2c8a7010eea510a.sol.txt is done!
# 0x12b2b2331a72d375c453c160b2c8a7010eea510a.sol
# 0x275b6a1abadcc1a994e5237006e68bf26d38b43d.sol.txt
# WARNING:binary_extractor.arch.evm.cfg:function signatures collision: ['ideal_warn_timed(uint256,uint128)', 'owner()']
# 0x275b6a1abadcc1a994e5237006e68bf26d38b43d.sol.txt is done!
# 0x275b6a1abadcc1a994e5237006e68bf26d38b43d.sol
# 0x488706a24af724795b9a011fc7245d363afe0f2c.sol.txt
# WARNING:binary_extractor.arch.evm.cfg:function signatures collision: ['decimals()', 'available_assert_time(uint16,uint64)']
# WARNING:binary_extractor.arch.evm.cfg:function signatures collision: ['symbol()', 'link_classic_internal(uint64,int64)']
# 0x488706a24af724795b9a011fc7245d363afe0f2c.sol.txt is done!
# 0x488706a24af724795b9a011fc7245d363afe0f2c.sol
# 0xef5771efadd0cc9dd78d97f77db167e6998f3249.sol.txt
# 0xef5771efadd0cc9dd78d97f77db167e6998f3249.sol.txt is done!
# 0xef5771efadd0cc9dd78d97f77db167e6998f3249.sol
# 0x3521d44a9787d0587a0a5033abe1081c4580cb60.sol.txt
# 0x3521d44a9787d0587a0a5033abe1081c4580cb60.sol.txt is done!
# 0x3521d44a9787d0587a0a5033abe1081c4580cb60.sol
# 0xeb84356cd552869cf60b7e5e164f681bfee92cde.sol.txt
# WARNING:binary_extractor.arch.evm.cfg:function signatures collision: ['ideal_warn_timed(uint256,uint128)', 'owner()']
# 0xeb84356cd552869cf60b7e5e164f681bfee92cde.sol.txt is done!
# 0xeb84356cd552869cf60b7e5e164f681bfee92cde.sol
# 0xa8106238a1a1545046e5a69ca5848c37b746c557.sol.txt
# WARNING:binary_extractor.arch.evm.cfg:function signatures collision: ['decimals()', 'available_assert_time(uint16,uint64)']
# WARNING:binary_extractor.arch.evm.cfg:function signatures collision: ['symbol()', 'link_classic_internal(uint64,int64)']
# WARNING:binary_extractor.arch.evm.emulator:[X] Loop detected, skipping JUMPI 0x7d4
# WARNING:binary_extractor.arch.evm.emulator:[X] push_instr.ssa %246 = #0x7D4
# WARNING:binary_extractor.arch.evm.emulator:[X] Loop detected, skipping JUMPI 0x6ee
# WARNING:binary_extractor.arch.evm.emulator:[X] push_instr.ssa %3B4 = #0x6EE
# WARNING:binary_extractor.arch.evm.emulator:[X] Loop detected, skipping JUMPI 0x63d
# WARNING:binary_extractor.arch.evm.emulator:[X] push_instr.ssa %523 = #0x63D
# WARNING:binary_extractor.arch.evm.emulator:[X] Loop detected, skipping JUMPI 0x583
# WARNING:binary_extractor.arch.evm.emulator:[X] push_instr.ssa %676 = #0x583
# 0xa8106238a1a1545046e5a69ca5848c37b746c557.sol.txt is done!
# 0xa8106238a1a1545046e5a69ca5848c37b746c557.sol
# 0x7acfa5b6fe450b1e278689440acb0d691975b9b2.sol.txt
# 0x7acfa5b6fe450b1e278689440acb0d691975b9b2.sol.txt is done!
# 0x7acfa5b6fe450b1e278689440acb0d691975b9b2.sol
# 0x0be4a987fd8dcbd2fff64ba4131d3a208307f667.sol.txt
# WARNING:binary_extractor.arch.evm.cfg:function signatures collision: ['ideal_warn_timed(uint256,uint128)', 'owner()']
# 0x0be4a987fd8dcbd2fff64ba4131d3a208307f667.sol.txt is done!
# 0x0be4a987fd8dcbd2fff64ba4131d3a208307f667.sol
# 0x8e41104d9d38f2dfae2e67882c18279ee00a3fe0.sol.txt
# 0x8e41104d9d38f2dfae2e67882c18279ee00a3fe0.sol.txt is done!
# 0x8e41104d9d38f2dfae2e67882c18279ee00a3fe0.sol
# 0x64921acb8fc1b54d7f774788a405b7cf1864cbff.sol.txt
# WARNING:binary_extractor.arch.evm.cfg:function signatures collision: ['ideal_warn_timed(uint256,uint128)', 'owner()']
# 0x64921acb8fc1b54d7f774788a405b7cf1864cbff.sol.txt is done!
# 0x64921acb8fc1b54d7f774788a405b7cf1864cbff.sol
# 0xdd8a513d11bd563e009f8e561c488ba7969470e1.sol.txt
# WARNING:binary_extractor.arch.evm.cfg:function signatures collision: ['decimals()', 'available_assert_time(uint16,uint64)']
# WARNING:binary_extractor.arch.evm.cfg:function signatures collision: ['collate_propagate_storage(bytes16)', 'burn(uint256)']
# WARNING:binary_extractor.arch.evm.cfg:function signatures collision: ['symbol()', 'link_classic_internal(uint64,int64)']
# WARNING:binary_extractor.arch.evm.emulator:[X] Loop detected, skipping JUMPI 0xcf3
# WARNING:binary_extractor.arch.evm.emulator:[X] push_instr.ssa %3A1 = #0xCF3
# WARNING:binary_extractor.arch.evm.emulator:[X] Loop detected, skipping JUMPI 0x6e7
# WARNING:binary_extractor.arch.evm.emulator:[X] push_instr.ssa %834 = #0x6E7
# 0xdd8a513d11bd563e009f8e561c488ba7969470e1.sol.txt is done!
# 0xdd8a513d11bd563e009f8e561c488ba7969470e1.sol
# 0xcc9028ff5fafcd8de09f4b96b82fce98cf3a590e.sol.txt
# WARNING:binary_extractor.arch.evm.cfg:function signatures collision: ['ideal_warn_timed(uint256,uint128)', 'owner()']
# 0xcc9028ff5fafcd8de09f4b96b82fce98cf3a590e.sol.txt is done!
# 0xcc9028ff5fafcd8de09f4b96b82fce98cf3a590e.sol
# 0xe9fa21e671bcfb04e6868784b89c19d5aa2424ea.sol.txt
# 0xe9fa21e671bcfb04e6868784b89c19d5aa2424ea.sol.txt is done!
# 0xe9fa21e671bcfb04e6868784b89c19d5aa2424ea.sol
# 0xe0b7927c4af23765cb51314a0e0521a9645f0e2a.sol.txt
# WARNING:binary_extractor.arch.evm.cfg:function signatures collision: ['ideal_warn_timed(uint256,uint128)', 'owner()']
# 0xe0b7927c4af23765cb51314a0e0521a9645f0e2a.sol.txt is done!
# 0xe0b7927c4af23765cb51314a0e0521a9645f0e2a.sol
# 0x3c67e228c56aeea9a421f230a8768fe134ac7639.sol.txt
# WARNING:binary_extractor.arch.evm.cfg:function signatures collision: ['ideal_warn_timed(uint256,uint128)', 'owner()']
# 0x3c67e228c56aeea9a421f230a8768fe134ac7639.sol.txt is done!
# 0x3c67e228c56aeea9a421f230a8768fe134ac7639.sol
# 0xca2796f9f61dc7b238aab043971e49c6164df375.sol.txt
# 0xca2796f9f61dc7b238aab043971e49c6164df375.sol.txt is done!
# 0xca2796f9f61dc7b238aab043971e49c6164df375.sol
# 0x78efe12ee9e61e954879f7a30445bbb72528963b.sol.txt
# WARNING:binary_extractor.arch.evm.cfg:function signatures collision: ['decimals()', 'available_assert_time(uint16,uint64)']
# WARNING:binary_extractor.arch.evm.cfg:function signatures collision: ['collate_propagate_storage(bytes16)', 'burn(uint256)']
# WARNING:binary_extractor.arch.evm.cfg:function signatures collision: ['symbol()', 'link_classic_internal(uint64,int64)']
# WARNING:binary_extractor.arch.evm.emulator:[X] Loop detected, skipping JUMPI 0xcf3
# WARNING:binary_extractor.arch.evm.emulator:[X] push_instr.ssa %3A2 = #0xCF3
# WARNING:binary_extractor.arch.evm.emulator:[X] Loop detected, skipping JUMPI 0x6e7
# WARNING:binary_extractor.arch.evm.emulator:[X] push_instr.ssa %836 = #0x6E7
# 0x78efe12ee9e61e954879f7a30445bbb72528963b.sol.txt is done!
# 0x78efe12ee9e61e954879f7a30445bbb72528963b.sol
# 0x7cf874fd2f5606ccbcc1b25cf9bed8bb263c5ecd.sol.txt
# 0x7cf874fd2f5606ccbcc1b25cf9bed8bb263c5ecd.sol.txt is done!
# 0x7cf874fd2f5606ccbcc1b25cf9bed8bb263c5ecd.sol
# 0x424bc5bfc7898644c91ca59eb9c47fad1a3a6384.sol.txt
# WARNING:binary_extractor.arch.evm.emulator:[X] Loop detected, skipping JUMPI 0x1dd
# WARNING:binary_extractor.arch.evm.emulator:[X] push_instr.ssa %B8 = #0x1DD
# 0x424bc5bfc7898644c91ca59eb9c47fad1a3a6384.sol.txt is done!
# 0x424bc5bfc7898644c91ca59eb9c47fad1a3a6384.sol
# 0x73fadd839ccc9097bbcc87e1f9af56157bc47dde.sol.txt
# WARNING:binary_extractor.arch.evm.cfg:function signatures collision: ['ideal_warn_timed(uint256,uint128)', 'owner()']
# 0x73fadd839ccc9097bbcc87e1f9af56157bc47dde.sol.txt is done!
# 0x73fadd839ccc9097bbcc87e1f9af56157bc47dde.sol
# 0x9165b1ed40c097073a7d15ad3ef49e3c5b132588.sol.txt
# WARNING:binary_extractor.arch.evm.cfg:function signatures collision: ['ideal_warn_timed(uint256,uint128)', 'owner()']
# 0x9165b1ed40c097073a7d15ad3ef49e3c5b132588.sol.txt is done!
# 0x9165b1ed40c097073a7d15ad3ef49e3c5b132588.sol
# 0x78230e69d6e6449db1e11904e0bd81c018454d7a.sol.txt
# WARNING:binary_extractor.arch.evm.cfg:function signatures collision: ['collate_propagate_storage(bytes16)', 'burn(uint256)']
# 0x78230e69d6e6449db1e11904e0bd81c018454d7a.sol.txt is done!
# 0x78230e69d6e6449db1e11904e0bd81c018454d7a.sol
# 14741.sol.txt
# WARNING:binary_extractor.arch.evm.cfg:function signatures collision: ['ideal_warn_timed(uint256,uint128)', 'owner()']
# 14741.sol.txt is done!
# 14741.sol
# 0xd43ff5612420c8bcc6316dcc15fedfb4b791df32.sol.txt
# 0xd43ff5612420c8bcc6316dcc15fedfb4b791df32.sol.txt is done!
# 0xd43ff5612420c8bcc6316dcc15fedfb4b791df32.sol
# 0xe65ee7c03bbb3c950cfd4895c24989afa233ef01.sol.txt
# WARNING:binary_extractor.arch.evm.cfg:function signatures collision: ['ideal_warn_timed(uint256,uint128)', 'owner()']
# 0xe65ee7c03bbb3c950cfd4895c24989afa233ef01.sol.txt is done!
# 0xe65ee7c03bbb3c950cfd4895c24989afa233ef01.sol
# 0x517c62136a2d0ba66d0590644c9763992253e90b.sol.txt
# WARNING:binary_extractor.arch.evm.cfg:function signatures collision: ['ideal_warn_timed(uint256,uint128)', 'owner()']
# 0x517c62136a2d0ba66d0590644c9763992253e90b.sol.txt is done!
# 0x517c62136a2d0ba66d0590644c9763992253e90b.sol
# 0x25a1de1c3ee658fe034b8914a1d8d34110423af8.sol.txt
# WARNING:binary_extractor.arch.evm.cfg:function signatures collision: ['ideal_warn_timed(uint256,uint128)', 'owner()']
# 0x25a1de1c3ee658fe034b8914a1d8d34110423af8.sol.txt is done!
# 0x25a1de1c3ee658fe034b8914a1d8d34110423af8.sol
# 0xa211785891eea553d98dedc901254797d5de756e.sol.txt
# WARNING:binary_extractor.arch.evm.cfg:function signatures collision: ['decimals()', 'available_assert_time(uint16,uint64)']
# WARNING:binary_extractor.arch.evm.cfg:function signatures collision: ['collate_propagate_storage(bytes16)', 'burn(uint256)']
# WARNING:binary_extractor.arch.evm.cfg:function signatures collision: ['ideal_warn_timed(uint256,uint128)', 'owner()']
# WARNING:binary_extractor.arch.evm.cfg:function signatures collision: ['symbol()', 'link_classic_internal(uint64,int64)']
# WARNING:binary_extractor.arch.evm.emulator:[X] Loop detected, skipping JUMPI 0x10be
# WARNING:binary_extractor.arch.evm.emulator:[X] push_instr.ssa %4D3 = #0x10BE
# WARNING:binary_extractor.arch.evm.emulator:[X] Loop detected, skipping JUMPI 0x8e8
# WARNING:binary_extractor.arch.evm.emulator:[X] push_instr.ssa %84B = #0x8E8
# 0xa211785891eea553d98dedc901254797d5de756e.sol.txt is done!
# 0xa211785891eea553d98dedc901254797d5de756e.sol
# 0x858a1465c6b9cf7649415b6fff157a7665be8595.sol.txt
# WARNING:binary_extractor.arch.evm.cfg:function signatures collision: ['decimals()', 'available_assert_time(uint16,uint64)']
# WARNING:binary_extractor.arch.evm.cfg:function signatures collision: ['symbol()', 'link_classic_internal(uint64,int64)']
# WARNING:binary_extractor.arch.evm.emulator:[X] Loop detected, skipping JUMPI 0xa5f
# WARNING:binary_extractor.arch.evm.emulator:[X] push_instr.ssa %1DD = #0xA5F
# WARNING:binary_extractor.arch.evm.emulator:[X] Loop detected, skipping JUMPI 0x4b0
# WARNING:binary_extractor.arch.evm.emulator:[X] push_instr.ssa %4CD = #0x4B0
# 0x858a1465c6b9cf7649415b6fff157a7665be8595.sol.txt is done!
# 0x858a1465c6b9cf7649415b6fff157a7665be8595.sol
# 0x411a4bf072d099069249846532acd874c131355e.sol.txt
# WARNING:binary_extractor.arch.evm.emulator:[X] Loop detected, skipping JUMPI 0x3fd
# WARNING:binary_extractor.arch.evm.emulator:[X] push_instr.ssa %8BE = #0x3FD
# 0x411a4bf072d099069249846532acd874c131355e.sol.txt is done!
# 0x411a4bf072d099069249846532acd874c131355e.sol
# 0x1e3fe98d1c89865b6b819bbfd532dadab3b34d2d.sol.txt
# 0x1e3fe98d1c89865b6b819bbfd532dadab3b34d2d.sol.txt is done!
# 0x1e3fe98d1c89865b6b819bbfd532dadab3b34d2d.sol
# 0xc1b57670e90d7c1e51ffc9a421a5dca40bf4f37d.sol.txt
# WARNING:binary_extractor.arch.evm.cfg:function signatures collision: ['collate_propagate_storage(bytes16)', 'burn(uint256)']
# 0xc1b57670e90d7c1e51ffc9a421a5dca40bf4f37d.sol.txt is done!
# 0xc1b57670e90d7c1e51ffc9a421a5dca40bf4f37d.sol
# 0x33931870dfbdc15ec7e03c7d7a9cac657c309d12.sol.txt
# 0x33931870dfbdc15ec7e03c7d7a9cac657c309d12.sol.txt is done!
# 0x33931870dfbdc15ec7e03c7d7a9cac657c309d12.sol
# 0x2fcc73982cda54b15941eaae842f93a31f879ef2.sol.txt
# WARNING:binary_extractor.arch.evm.cfg:function signatures collision: ['collate_propagate_storage(bytes16)', 'burn(uint256)']
# 0x2fcc73982cda54b15941eaae842f93a31f879ef2.sol.txt is done!
# 0x2fcc73982cda54b15941eaae842f93a31f879ef2.sol
# 0x6eaa66453b4b8d21be737891e1056a1e801ac264.sol.txt
# WARNING:binary_extractor.arch.evm.cfg:function signatures collision: ['decimals()', 'available_assert_time(uint16,uint64)']
# WARNING:binary_extractor.arch.evm.cfg:function signatures collision: ['collate_propagate_storage(bytes16)', 'burn(uint256)']
# WARNING:binary_extractor.arch.evm.cfg:function signatures collision: ['ideal_warn_timed(uint256,uint128)', 'owner()']
# WARNING:binary_extractor.arch.evm.cfg:function signatures collision: ['symbol()', 'link_classic_internal(uint64,int64)']
# 0x6eaa66453b4b8d21be737891e1056a1e801ac264.sol.txt is done!
# 0x6eaa66453b4b8d21be737891e1056a1e801ac264.sol
# 0xac3211a5025414af2866ff09c23fc18bc97e79b1.sol.txt
# WARNING:binary_extractor.arch.evm.cfg:function signatures collision: ['collate_propagate_storage(bytes16)', 'burn(uint256)']
# 0xac3211a5025414af2866ff09c23fc18bc97e79b1.sol.txt is done!
# 0xac3211a5025414af2866ff09c23fc18bc97e79b1.sol
# 0xd4078bdb652610ad5383a747d130cbe905911102.sol.txt
# WARNING:binary_extractor.arch.evm.cfg:function signatures collision: ['decimals()', 'available_assert_time(uint16,uint64)']
# WARNING:binary_extractor.arch.evm.cfg:function signatures collision: ['collate_propagate_storage(bytes16)', 'burn(uint256)']
# WARNING:binary_extractor.arch.evm.cfg:function signatures collision: ['ideal_warn_timed(uint256,uint128)', 'owner()']
# WARNING:binary_extractor.arch.evm.cfg:function signatures collision: ['symbol()', 'link_classic_internal(uint64,int64)']
# 0xd4078bdb652610ad5383a747d130cbe905911102.sol.txt is done!
# 0xd4078bdb652610ad5383a747d130cbe905911102.sol
# 0x13339fd07934cd674269726edf3b5ccee9dd93de.sol.txt
# 0x13339fd07934cd674269726edf3b5ccee9dd93de.sol.txt is done!
# 0x13339fd07934cd674269726edf3b5ccee9dd93de.sol
# 0x2f41f7fc1d45749e0a7498c659d997a1f8fe9f46.sol.txt
# WARNING:binary_extractor.arch.evm.cfg:function signatures collision: ['ideal_warn_timed(uint256,uint128)', 'owner()']
# 0x2f41f7fc1d45749e0a7498c659d997a1f8fe9f46.sol.txt is done!
# 0x2f41f7fc1d45749e0a7498c659d997a1f8fe9f46.sol
# 0x466f39a5fd8d1bd54ea7e82975177c0f00c68492.sol.txt
# WARNING:binary_extractor.arch.evm.cfg:function signatures collision: ['ideal_warn_timed(uint256,uint128)', 'owner()']
# 0x466f39a5fd8d1bd54ea7e82975177c0f00c68492.sol.txt is done!
# 0x466f39a5fd8d1bd54ea7e82975177c0f00c68492.sol
# 0x5bfc1ff7f9e087c64fefb34f2e7cf24e5570919f.sol.txt
# WARNING:binary_extractor.arch.evm.cfg:function signatures collision: ['ideal_warn_timed(uint256,uint128)', 'owner()']
# 0x5bfc1ff7f9e087c64fefb34f2e7cf24e5570919f.sol.txt is done!
# 0x5bfc1ff7f9e087c64fefb34f2e7cf24e5570919f.sol
# 0x3a2a7ad49b34ad5777806a78110da234381d8863.sol.txt
# WARNING:binary_extractor.arch.evm.cfg:function signatures collision: ['ideal_warn_timed(uint256,uint128)', 'owner()']
# 0x3a2a7ad49b34ad5777806a78110da234381d8863.sol.txt is done!
# 0x3a2a7ad49b34ad5777806a78110da234381d8863.sol
# 0x16ea01acb4b0bca2000ee5473348b6937ee6f72f.sol.txt
# WARNING:binary_extractor.arch.evm.cfg:function signatures collision: ['ideal_warn_timed(uint256,uint128)', 'owner()']
# 0x16ea01acb4b0bca2000ee5473348b6937ee6f72f.sol.txt is done!
# 0x16ea01acb4b0bca2000ee5473348b6937ee6f72f.sol
# 0xc4d557d795ce16c49624e48045b380f169e4113f.sol.txt
# 0xc4d557d795ce16c49624e48045b380f169e4113f.sol.txt is done!
# 0xc4d557d795ce16c49624e48045b380f169e4113f.sol
# 3985.sol.txt
# 3985.sol.txt is done!
# 3985.sol
# 0x69b405d404fdacab21909cffafee7f02c106e9dd.sol.txt
# WARNING:binary_extractor.arch.evm.cfg:function signatures collision: ['decimals()', 'available_assert_time(uint16,uint64)']
# WARNING:binary_extractor.arch.evm.cfg:function signatures collision: ['ideal_warn_timed(uint256,uint128)', 'owner()']
# WARNING:binary_extractor.arch.evm.cfg:function signatures collision: ['symbol()', 'link_classic_internal(uint64,int64)']
# WARNING:binary_extractor.arch.evm.emulator:[X] Loop detected, skipping JUMPI 0xdc0
# WARNING:binary_extractor.arch.evm.emulator:[X] push_instr.ssa %3E6 = #0xDC0
# WARNING:binary_extractor.arch.evm.emulator:[X] Loop detected, skipping JUMPI 0x70a
# WARNING:binary_extractor.arch.evm.emulator:[X] push_instr.ssa %6FB = #0x70A
# 0x69b405d404fdacab21909cffafee7f02c106e9dd.sol.txt is done!
# 0x69b405d404fdacab21909cffafee7f02c106e9dd.sol
# 0x107f410758055bbad878913aa7a2a444b324c546.sol.txt
# WARNING:binary_extractor.arch.evm.emulator:[X] Loop detected, skipping JUMPI 0x17f7
# WARNING:binary_extractor.arch.evm.emulator:[X] push_instr.ssa %146 = #0x17F7
# 0x107f410758055bbad878913aa7a2a444b324c546.sol.txt is done!
# 0x107f410758055bbad878913aa7a2a444b324c546.sol
# 0xf279585a0c4ebe2471be7dac0c5ff6372636df55.sol.txt
# 0xf279585a0c4ebe2471be7dac0c5ff6372636df55.sol.txt is done!
# 0xf279585a0c4ebe2471be7dac0c5ff6372636df55.sol
# 0xa918185d042016e2d87c5cb0c7d216b062f79559.sol.txt
# 0xa918185d042016e2d87c5cb0c7d216b062f79559.sol.txt is done!
# 0xa918185d042016e2d87c5cb0c7d216b062f79559.sol
# 0x6556d2ec4d96da39cf75cbe50d58fae90079800a.sol.txt
# 0x6556d2ec4d96da39cf75cbe50d58fae90079800a.sol.txt is done!
# 0x6556d2ec4d96da39cf75cbe50d58fae90079800a.sol
# 0x4a1dc7fe002a24c866e54e50907fe09402eee961.sol.txt
# WARNING:binary_extractor.arch.evm.cfg:function signatures collision: ['decimals()', 'available_assert_time(uint16,uint64)']
# WARNING:binary_extractor.arch.evm.cfg:function signatures collision: ['symbol()', 'link_classic_internal(uint64,int64)']
# WARNING:binary_extractor.arch.evm.emulator:[X] Loop detected, skipping JUMPI 0xc09
# WARNING:binary_extractor.arch.evm.emulator:[X] push_instr.ssa %28F = #0xC09
# WARNING:binary_extractor.arch.evm.emulator:[X] Loop detected, skipping JUMPI 0x592
# WARNING:binary_extractor.arch.evm.emulator:[X] push_instr.ssa %5E8 = #0x592
# 0x4a1dc7fe002a24c866e54e50907fe09402eee961.sol.txt is done!
# 0x4a1dc7fe002a24c866e54e50907fe09402eee961.sol
# 0xf6abff616043c2da572573dcc583b656297b30e7.sol.txt
# WARNING:binary_extractor.arch.evm.cfg:function signatures collision: ['decimals()', 'available_assert_time(uint16,uint64)']
# WARNING:binary_extractor.arch.evm.cfg:function signatures collision: ['collate_propagate_storage(bytes16)', 'burn(uint256)']
# WARNING:binary_extractor.arch.evm.cfg:function signatures collision: ['ideal_warn_timed(uint256,uint128)', 'owner()']
# WARNING:binary_extractor.arch.evm.cfg:function signatures collision: ['symbol()', 'link_classic_internal(uint64,int64)']
# 0xf6abff616043c2da572573dcc583b656297b30e7.sol.txt is done!
# 0xf6abff616043c2da572573dcc583b656297b30e7.sol
# 36645.sol.txt
# 36645.sol.txt is done!
# 36645.sol
# 0x67a2f7c7ec5ba1c1be768d8065d71566cadfdeef.sol.txt
# WARNING:binary_extractor.arch.evm.cfg:function signatures collision: ['collate_propagate_storage(bytes16)', 'burn(uint256)']
# 0x67a2f7c7ec5ba1c1be768d8065d71566cadfdeef.sol.txt is done!
# 0x67a2f7c7ec5ba1c1be768d8065d71566cadfdeef.sol
# 0xf1b47c39327883f6bd90f5f16473594b2c257eec.sol.txt
# WARNING:binary_extractor.arch.evm.cfg:function signatures collision: ['ideal_warn_timed(uint256,uint128)', 'owner()']
# 0xf1b47c39327883f6bd90f5f16473594b2c257eec.sol.txt is done!
# 0xf1b47c39327883f6bd90f5f16473594b2c257eec.sol
# 0x10a34bbe9b3c5ad536ca23d5eefa81ca448e92ff.sol.txt
# 0x10a34bbe9b3c5ad536ca23d5eefa81ca448e92ff.sol.txt is done!
# 0x10a34bbe9b3c5ad536ca23d5eefa81ca448e92ff.sol
# 0x634446285f22aa660b36424ecd27455ab9bde51c.sol.txt
# WARNING:binary_extractor.arch.evm.cfg:function signatures collision: ['decimals()', 'available_assert_time(uint16,uint64)']
# WARNING:binary_extractor.arch.evm.cfg:function signatures collision: ['ideal_warn_timed(uint256,uint128)', 'owner()']
# WARNING:binary_extractor.arch.evm.cfg:function signatures collision: ['symbol()', 'link_classic_internal(uint64,int64)']
# 0x634446285f22aa660b36424ecd27455ab9bde51c.sol.txt is done!
# 0x634446285f22aa660b36424ecd27455ab9bde51c.sol
# 0x4e570c49b27aaa187a7fef9ca8b3bdd1e9e36fb2.sol.txt
# 0x4e570c49b27aaa187a7fef9ca8b3bdd1e9e36fb2.sol.txt is done!
# 0x4e570c49b27aaa187a7fef9ca8b3bdd1e9e36fb2.sol
# 0x42f2d09a9471cc2cf0092e5c1aa55aa099041519.sol.txt
# 0x42f2d09a9471cc2cf0092e5c1aa55aa099041519.sol.txt is done!
# 0x42f2d09a9471cc2cf0092e5c1aa55aa099041519.sol
# 0x34d264fadcae674c4aaea6d795b4d1448feb038b.sol.txt
# WARNING:binary_extractor.arch.evm.cfg:function signatures collision: ['collate_propagate_storage(bytes16)', 'burn(uint256)']
# 0x34d264fadcae674c4aaea6d795b4d1448feb038b.sol.txt is done!
# 0x34d264fadcae674c4aaea6d795b4d1448feb038b.sol
# 0xecd2f5afcf2a987e3f1c8ae7f4c1b1a60358a6ca.sol.txt
# WARNING:binary_extractor.arch.evm.cfg:function signatures collision: ['ideal_warn_timed(uint256,uint128)', 'owner()']
# 0xecd2f5afcf2a987e3f1c8ae7f4c1b1a60358a6ca.sol.txt is done!
# 0xecd2f5afcf2a987e3f1c8ae7f4c1b1a60358a6ca.sol
# 0x117b4ff6e29baa41592fbc02abd2c0b40110d6e6.sol.txt
# 0x117b4ff6e29baa41592fbc02abd2c0b40110d6e6.sol.txt is done!
# 0x117b4ff6e29baa41592fbc02abd2c0b40110d6e6.sol
# 0xffcc30dad3570b97a3d24cca0333cac4cef5dbaf.sol.txt
# 0xffcc30dad3570b97a3d24cca0333cac4cef5dbaf.sol.txt is done!
# 0xffcc30dad3570b97a3d24cca0333cac4cef5dbaf.sol
# 0x014b50466590340d41307cc54dcee990c8d58aa8.sol.txt
# 0x014b50466590340d41307cc54dcee990c8d58aa8.sol.txt is done!
# 0x014b50466590340d41307cc54dcee990c8d58aa8.sol
# 0xcff1e75e90cce12866135dd6e7bf94892716ec58.sol.txt
# WARNING:binary_extractor.arch.evm.cfg:function signatures collision: ['decimals()', 'available_assert_time(uint16,uint64)']
# WARNING:binary_extractor.arch.evm.cfg:function signatures collision: ['symbol()', 'link_classic_internal(uint64,int64)']
# WARNING:binary_extractor.arch.evm.emulator:[X] Loop detected, skipping JUMPI 0x2d7
# WARNING:binary_extractor.arch.evm.emulator:[X] push_instr.ssa %BC = #0x2D7
# WARNING:binary_extractor.arch.evm.emulator:[X] Loop detected, skipping JUMPI 0x226
# WARNING:binary_extractor.arch.evm.emulator:[X] push_instr.ssa %219 = #0x226
# 0xcff1e75e90cce12866135dd6e7bf94892716ec58.sol.txt is done!
# 0xcff1e75e90cce12866135dd6e7bf94892716ec58.sol
# 0xa9587915625a3d5fbd276762e532aaabe2ad3e2f.sol.txt
# WARNING:binary_extractor.arch.evm.cfg:function signatures collision: ['collate_propagate_storage(bytes16)', 'burn(uint256)']
# WARNING:binary_extractor.arch.evm.cfg:function signatures collision: ['ideal_warn_timed(uint256,uint128)', 'owner()']
# 0xa9587915625a3d5fbd276762e532aaabe2ad3e2f.sol.txt is done!
# 0xa9587915625a3d5fbd276762e532aaabe2ad3e2f.sol
# 0x6a7ec9df733435c7e7702ac3ddbb48ecfe299a5d.sol.txt
# WARNING:binary_extractor.arch.evm.cfg:function signatures collision: ['decimals()', 'available_assert_time(uint16,uint64)']
# WARNING:binary_extractor.arch.evm.cfg:function signatures collision: ['collate_propagate_storage(bytes16)', 'burn(uint256)']
# WARNING:binary_extractor.arch.evm.cfg:function signatures collision: ['symbol()', 'link_classic_internal(uint64,int64)']
# WARNING:binary_extractor.arch.evm.emulator:[X] Loop detected, skipping JUMPI 0xcf3
# WARNING:binary_extractor.arch.evm.emulator:[X] push_instr.ssa %3A2 = #0xCF3
# WARNING:binary_extractor.arch.evm.emulator:[X] Loop detected, skipping JUMPI 0x6e7
# WARNING:binary_extractor.arch.evm.emulator:[X] push_instr.ssa %836 = #0x6E7
# 0x6a7ec9df733435c7e7702ac3ddbb48ecfe299a5d.sol.txt is done!
# 0x6a7ec9df733435c7e7702ac3ddbb48ecfe299a5d.sol
# 0x03966330e7f60c95d2d8dd043735eea901c5e4e0.sol.txt
# WARNING:binary_extractor.arch.evm.cfg:function signatures collision: ['ideal_warn_timed(uint256,uint128)', 'owner()']
# 0x03966330e7f60c95d2d8dd043735eea901c5e4e0.sol.txt is done!
# 0x03966330e7f60c95d2d8dd043735eea901c5e4e0.sol
# 0x57409c375540bd4a29d64431e1e0b74ba7e12b6a.sol.txt
# WARNING:binary_extractor.arch.evm.emulator:[X] Loop detected, skipping JUMPI 0x272
# WARNING:binary_extractor.arch.evm.emulator:[X] push_instr.ssa %1EE = #0x272
# 0x57409c375540bd4a29d64431e1e0b74ba7e12b6a.sol.txt is done!
# 0x57409c375540bd4a29d64431e1e0b74ba7e12b6a.sol
# 0x4973eda29d48cf5e46065ce5d77c9b9f148a44cf.sol.txt
# WARNING:binary_extractor.arch.evm.cfg:function signatures collision: ['decimals()', 'available_assert_time(uint16,uint64)']
# WARNING:binary_extractor.arch.evm.cfg:function signatures collision: ['ideal_warn_timed(uint256,uint128)', 'owner()']
# WARNING:binary_extractor.arch.evm.cfg:function signatures collision: ['symbol()', 'link_classic_internal(uint64,int64)']
# WARNING:binary_extractor.arch.evm.emulator:[X] Loop detected, skipping JUMPI 0xea4
# WARNING:binary_extractor.arch.evm.emulator:[X] push_instr.ssa %374 = #0xEA4
# WARNING:binary_extractor.arch.evm.emulator:[X] Loop detected, skipping JUMPI 0x6d6
# WARNING:binary_extractor.arch.evm.emulator:[X] push_instr.ssa %756 = #0x6D6
# 0x4973eda29d48cf5e46065ce5d77c9b9f148a44cf.sol.txt is done!
# 0x4973eda29d48cf5e46065ce5d77c9b9f148a44cf.sol
# 0x0a7073207bac23865e0e3b204615364b5a9d3783.sol.txt
# 0x0a7073207bac23865e0e3b204615364b5a9d3783.sol.txt is done!
# 0x0a7073207bac23865e0e3b204615364b5a9d3783.sol
# 0x034f8165470b0a26b8daac1c3cd1cc6156e8294d.sol.txt
# WARNING:binary_extractor.arch.evm.cfg:function signatures collision: ['ideal_warn_timed(uint256,uint128)', 'owner()']
# 0x034f8165470b0a26b8daac1c3cd1cc6156e8294d.sol.txt is done!
# 0x034f8165470b0a26b8daac1c3cd1cc6156e8294d.sol
# 0xbc75eea7d7e86376fb68680573042de02f39ac80.sol.txt
# 0xbc75eea7d7e86376fb68680573042de02f39ac80.sol.txt is done!
# 0xbc75eea7d7e86376fb68680573042de02f39ac80.sol
# 0xee6bd04c6164d7f0fa1cb03277c855639d99a7f6.sol.txt
# 0xee6bd04c6164d7f0fa1cb03277c855639d99a7f6.sol.txt is done!
# 0xee6bd04c6164d7f0fa1cb03277c855639d99a7f6.sol
# 0xccbf21ba6ef00802ab06637896b799f7101f54a2.sol.txt
# 0xccbf21ba6ef00802ab06637896b799f7101f54a2.sol.txt is done!
# 0xccbf21ba6ef00802ab06637896b799f7101f54a2.sol
# 0x2cbb9161049920eba8dc50e520d10605a7ec9584.sol.txt
# WARNING:binary_extractor.arch.evm.cfg:function signatures collision: ['ideal_warn_timed(uint256,uint128)', 'owner()']
# 0x2cbb9161049920eba8dc50e520d10605a7ec9584.sol.txt is done!
# 0x2cbb9161049920eba8dc50e520d10605a7ec9584.sol
# 0x24457c48cbd0e1e502beffd26616b6f4ee85718a.sol.txt
# 0x24457c48cbd0e1e502beffd26616b6f4ee85718a.sol.txt is done!
# 0x24457c48cbd0e1e502beffd26616b6f4ee85718a.sol
# 0x3c840e8a7b4e28c12071fc92108b2d8a266d2c9b.sol.txt
# 0x3c840e8a7b4e28c12071fc92108b2d8a266d2c9b.sol.txt is done!
# 0x3c840e8a7b4e28c12071fc92108b2d8a266d2c9b.sol
# 0x1b1ee205ee5a269ee34805192763b21ef84aa1b6.sol.txt
# WARNING:binary_extractor.arch.evm.cfg:function signatures collision: ['decimals()', 'available_assert_time(uint16,uint64)']
# WARNING:binary_extractor.arch.evm.cfg:function signatures collision: ['collate_propagate_storage(bytes16)', 'burn(uint256)']
# WARNING:binary_extractor.arch.evm.cfg:function signatures collision: ['ideal_warn_timed(uint256,uint128)', 'owner()']
# WARNING:binary_extractor.arch.evm.cfg:function signatures collision: ['symbol()', 'link_classic_internal(uint64,int64)']
# WARNING:binary_extractor.arch.evm.emulator:[X] Loop detected, skipping JUMPI 0x122f
# WARNING:binary_extractor.arch.evm.emulator:[X] push_instr.ssa %68D = #0x122F
# WARNING:binary_extractor.arch.evm.emulator:[X] Loop detected, skipping JUMPI 0xa6b
# WARNING:binary_extractor.arch.evm.emulator:[X] push_instr.ssa %BD4 = #0xA6B
# 0x1b1ee205ee5a269ee34805192763b21ef84aa1b6.sol.txt is done!
# 0x1b1ee205ee5a269ee34805192763b21ef84aa1b6.sol
# 0x71396a6410249725c5609646c4e449c6c4d41e27.sol.txt
# WARNING:binary_extractor.arch.evm.cfg:function signatures collision: ['decimals()', 'available_assert_time(uint16,uint64)']
# WARNING:binary_extractor.arch.evm.cfg:function signatures collision: ['symbol()', 'link_classic_internal(uint64,int64)']
# WARNING:binary_extractor.arch.evm.emulator:[X] Loop detected, skipping JUMPI 0xc91
# WARNING:binary_extractor.arch.evm.emulator:[X] push_instr.ssa %297 = #0xC91
# WARNING:binary_extractor.arch.evm.emulator:[X] Loop detected, skipping JUMPI 0x604
# WARNING:binary_extractor.arch.evm.emulator:[X] push_instr.ssa %624 = #0x604
# 0x71396a6410249725c5609646c4e449c6c4d41e27.sol.txt is done!
# 0x71396a6410249725c5609646c4e449c6c4d41e27.sol
# 0x67446b5f69ea822715375e83edbf751e749e4638.sol.txt
# 0x67446b5f69ea822715375e83edbf751e749e4638.sol.txt is done!
# 0x67446b5f69ea822715375e83edbf751e749e4638.sol
# 0xb110e378ea8b83dd52d1c5a810a5dcf99bbc96ae.sol.txt
# WARNING:binary_extractor.arch.evm.cfg:function signatures collision: ['ideal_warn_timed(uint256,uint128)', 'owner()']
# 0xb110e378ea8b83dd52d1c5a810a5dcf99bbc96ae.sol.txt is done!
# 0xb110e378ea8b83dd52d1c5a810a5dcf99bbc96ae.sol
# 0xc3a1c1eea96588fc1f67f29fac5526225b1a16ae.sol.txt
# WARNING:binary_extractor.arch.evm.cfg:function signatures collision: ['decimals()', 'available_assert_time(uint16,uint64)']
# WARNING:binary_extractor.arch.evm.cfg:function signatures collision: ['symbol()', 'link_classic_internal(uint64,int64)']
# 0xc3a1c1eea96588fc1f67f29fac5526225b1a16ae.sol.txt is done!
# 0xc3a1c1eea96588fc1f67f29fac5526225b1a16ae.sol
# 0x57ffa14de96e7a761750fdf41c9496214a6dca2a.sol.txt
# WARNING:binary_extractor.arch.evm.cfg:function signatures collision: ['collate_propagate_storage(bytes16)', 'burn(uint256)']
# 0x57ffa14de96e7a761750fdf41c9496214a6dca2a.sol.txt is done!
# 0x57ffa14de96e7a761750fdf41c9496214a6dca2a.sol
# 0x0000000fdf9eb269b38e39e058f45d7d0ddb60f9.sol.txt
# 0x0000000fdf9eb269b38e39e058f45d7d0ddb60f9.sol.txt is done!
# 0x0000000fdf9eb269b38e39e058f45d7d0ddb60f9.sol
# 0x735af341f2d9ce3663616cd84ff522dbf62fbc1f.sol.txt
# 0x735af341f2d9ce3663616cd84ff522dbf62fbc1f.sol.txt is done!
# 0x735af341f2d9ce3663616cd84ff522dbf62fbc1f.sol
# 0x8ac16c08105de55a02e2b7462b1eec6085fa4d86.sol.txt
# 0x8ac16c08105de55a02e2b7462b1eec6085fa4d86.sol.txt is done!
# 0x8ac16c08105de55a02e2b7462b1eec6085fa4d86.sol
# 0xe463d1ee18bcbce681215d15738018eadaa82260.sol.txt
# 0xe463d1ee18bcbce681215d15738018eadaa82260.sol.txt is done!
# 0xe463d1ee18bcbce681215d15738018eadaa82260.sol
# 0xb70c8d81c7b70c3d64d1c02551dcfa0b6f2a99ea.sol.txt
# WARNING:binary_extractor.arch.evm.cfg:function signatures collision: ['ideal_warn_timed(uint256,uint128)', 'owner()']
# 0xb70c8d81c7b70c3d64d1c02551dcfa0b6f2a99ea.sol.txt is done!
# 0xb70c8d81c7b70c3d64d1c02551dcfa0b6f2a99ea.sol
# 0xb9c37445b9564652a4b46ffbdf6dbf0d53e0605f.sol.txt
# 0xb9c37445b9564652a4b46ffbdf6dbf0d53e0605f.sol.txt is done!
# 0xb9c37445b9564652a4b46ffbdf6dbf0d53e0605f.sol
# 4472.sol.txt
# 4472.sol.txt is done!
# 4472.sol
# 0x65171f081c03487d80687850683922a151be11d2.sol.txt
# 0x65171f081c03487d80687850683922a151be11d2.sol.txt is done!
# 0x65171f081c03487d80687850683922a151be11d2.sol
# 0x254634aa44d6d7d422a829a8a2883a097be482c2.sol.txt
# 0x254634aa44d6d7d422a829a8a2883a097be482c2.sol.txt is done!
# 0x254634aa44d6d7d422a829a8a2883a097be482c2.sol
# 0x970adfdfae44bc1721f7de1b8cf0ee801d3e6dab.sol.txt
# WARNING:binary_extractor.arch.evm.cfg:function signatures collision: ['ideal_warn_timed(uint256,uint128)', 'owner()']
# 0x970adfdfae44bc1721f7de1b8cf0ee801d3e6dab.sol.txt is done!
# 0x970adfdfae44bc1721f7de1b8cf0ee801d3e6dab.sol
# 0xa368d5a0dc530fe48883e742b817164ba6d91c4e.sol.txt
# 0xa368d5a0dc530fe48883e742b817164ba6d91c4e.sol.txt is done!
# 0xa368d5a0dc530fe48883e742b817164ba6d91c4e.sol
# 0x5e2b9e760685b8030af6e510a9ebd90a5cbf4263.sol.txt
# WARNING:binary_extractor.arch.evm.cfg:function signatures collision: ['ideal_warn_timed(uint256,uint128)', 'owner()']
# 0x5e2b9e760685b8030af6e510a9ebd90a5cbf4263.sol.txt is done!
# 0x5e2b9e760685b8030af6e510a9ebd90a5cbf4263.sol
# 0x9e4e85adcdc8149d96ec7845ca40c0ea1136f756.sol.txt
# 0x9e4e85adcdc8149d96ec7845ca40c0ea1136f756.sol.txt is done!
# 0x9e4e85adcdc8149d96ec7845ca40c0ea1136f756.sol
# 36334.sol.txt
# WARNING:binary_extractor.arch.evm.cfg:function signatures collision: ['ideal_warn_timed(uint256,uint128)', 'owner()']
# 36334.sol.txt is done!
# 36334.sol
# 0xbe6b696607afe72f2cb7a47b0fbdb32c5e5f073c.sol.txt
# 0xbe6b696607afe72f2cb7a47b0fbdb32c5e5f073c.sol.txt is done!
# 0xbe6b696607afe72f2cb7a47b0fbdb32c5e5f073c.sol
# 0x459c780413b46552e2314f5840cab416e4b689af.sol.txt
# WARNING:binary_extractor.arch.evm.cfg:function signatures collision: ['ideal_warn_timed(uint256,uint128)', 'owner()']
# 0x459c780413b46552e2314f5840cab416e4b689af.sol.txt is done!
# 0x459c780413b46552e2314f5840cab416e4b689af.sol
# 0x6a3120d8a66fe96eb260cce4b6da02e7835b8426.sol.txt
# 0x6a3120d8a66fe96eb260cce4b6da02e7835b8426.sol.txt is done!
# 0x6a3120d8a66fe96eb260cce4b6da02e7835b8426.sol
# 0x96b709bbc1454716857605db9c942544668af79b.sol.txt
# WARNING:binary_extractor.arch.evm.cfg:function signatures collision: ['ideal_warn_timed(uint256,uint128)', 'owner()']
# 0x96b709bbc1454716857605db9c942544668af79b.sol.txt is done!
# 0x96b709bbc1454716857605db9c942544668af79b.sol
# 0x02ab3549536c140af39ebb1c42f25a8e70b4a10a.sol.txt
# WARNING:binary_extractor.arch.evm.cfg:function signatures collision: ['ideal_warn_timed(uint256,uint128)', 'owner()']
# 0x02ab3549536c140af39ebb1c42f25a8e70b4a10a.sol.txt is done!
# 0x02ab3549536c140af39ebb1c42f25a8e70b4a10a.sol
# 0x5973376b603268fe4251d13040226078257014f8.sol.txt
# WARNING:binary_extractor.arch.evm.cfg:function signatures collision: ['ideal_warn_timed(uint256,uint128)', 'owner()']
# 0x5973376b603268fe4251d13040226078257014f8.sol.txt is done!
# 0x5973376b603268fe4251d13040226078257014f8.sol
# 0xa2b5ceb15354343c6f7a1569ac250cdd9b0634ba.sol.txt
# 0xa2b5ceb15354343c6f7a1569ac250cdd9b0634ba.sol.txt is done!
# 0xa2b5ceb15354343c6f7a1569ac250cdd9b0634ba.sol
# 0x8b79656fc38a04044e495e22fad747126ca305c4.sol.txt
# WARNING:binary_extractor.arch.evm.cfg:function signatures collision: ['collate_propagate_storage(bytes16)', 'burn(uint256)']
# WARNING:binary_extractor.arch.evm.cfg:function signatures collision: ['ideal_warn_timed(uint256,uint128)', 'owner()']
# 0x8b79656fc38a04044e495e22fad747126ca305c4.sol.txt is done!
# 0x8b79656fc38a04044e495e22fad747126ca305c4.sol
# 0x8a772004af0b8fca5e7093c6f277ba7b0e8fa97a.sol.txt
# WARNING:binary_extractor.arch.evm.cfg:function signatures collision: ['ideal_warn_timed(uint256,uint128)', 'owner()']
# 0x8a772004af0b8fca5e7093c6f277ba7b0e8fa97a.sol.txt is done!
# 0x8a772004af0b8fca5e7093c6f277ba7b0e8fa97a.sol
# 0x0ce80662769f22fd161e5e92cfc82121c835e097.sol.txt
# WARNING:binary_extractor.arch.evm.cfg:function signatures collision: ['ideal_warn_timed(uint256,uint128)', 'owner()']
# 0x0ce80662769f22fd161e5e92cfc82121c835e097.sol.txt is done!
# 0x0ce80662769f22fd161e5e92cfc82121c835e097.sol
# 0x6c1d5d7a21dac4d4db2f43bb2d737fc8a2aabd94.sol.txt
# WARNING:binary_extractor.arch.evm.cfg:function signatures collision: ['decimals()', 'available_assert_time(uint16,uint64)']
# WARNING:binary_extractor.arch.evm.cfg:function signatures collision: ['symbol()', 'link_classic_internal(uint64,int64)']
# 0x6c1d5d7a21dac4d4db2f43bb2d737fc8a2aabd94.sol.txt is done!
# 0x6c1d5d7a21dac4d4db2f43bb2d737fc8a2aabd94.sol
# 39994.sol.txt
# WARNING:binary_extractor.arch.evm.cfg:function signatures collision: ['symbol()', 'link_classic_internal(uint64,int64)']
# WARNING:binary_extractor.arch.evm.emulator:[X] Loop detected, skipping JUMPI 0x382
# WARNING:binary_extractor.arch.evm.emulator:[X] push_instr.ssa %11A = #0x382
# WARNING:binary_extractor.arch.evm.emulator:[X] Loop detected, skipping JUMPI 0x2de
# WARNING:binary_extractor.arch.evm.emulator:[X] push_instr.ssa %26D = #0x2DE
# 39994.sol.txt is done!
# 39994.sol
# 0xca1746f3e6e9098c9b11290fc7f2887741dbad80.sol.txt
# WARNING:binary_extractor.arch.evm.cfg:function signatures collision: ['ideal_warn_timed(uint256,uint128)', 'owner()']
# 0xca1746f3e6e9098c9b11290fc7f2887741dbad80.sol.txt is done!
# 0xca1746f3e6e9098c9b11290fc7f2887741dbad80.sol
# 0xe31f159cdc3370aec8ef5fbf3b7fce23766155f5.sol.txt
# WARNING:binary_extractor.arch.evm.cfg:function signatures collision: ['ideal_warn_timed(uint256,uint128)', 'owner()']
# WARNING:binary_extractor.arch.evm.emulator:[X] Loop detected, skipping JUMPI 0xada
# WARNING:binary_extractor.arch.evm.emulator:[X] push_instr.ssa %33A = #0xADA
# WARNING:binary_extractor.arch.evm.emulator:[X] Loop detected, skipping JUMPI 0x97d
# WARNING:binary_extractor.arch.evm.emulator:[X] push_instr.ssa %538 = #0x97D
# 0xe31f159cdc3370aec8ef5fbf3b7fce23766155f5.sol.txt is done!
# 0xe31f159cdc3370aec8ef5fbf3b7fce23766155f5.sol
# 0xff02b17386f94da201cff84a6a7482ec2c452ef3.sol.txt
# 0xff02b17386f94da201cff84a6a7482ec2c452ef3.sol.txt is done!
# 0xff02b17386f94da201cff84a6a7482ec2c452ef3.sol
# 0x3127be52acba38beab6b4b3a406dc04e557c037c.sol.txt
# 0x3127be52acba38beab6b4b3a406dc04e557c037c.sol.txt is done!
# 0x3127be52acba38beab6b4b3a406dc04e557c037c.sol
# 0x35a5cb585d51d836922b78a9bb1f5c04635c39b6.sol.txt
# 0x35a5cb585d51d836922b78a9bb1f5c04635c39b6.sol.txt is done!
# 0x35a5cb585d51d836922b78a9bb1f5c04635c39b6.sol
# 0x57ff71ff2a508ddc8016f22d27e0a02fef9c0f88.sol.txt
# WARNING:binary_extractor.arch.evm.cfg:function signatures collision: ['decimals()', 'available_assert_time(uint16,uint64)']
# WARNING:binary_extractor.arch.evm.cfg:function signatures collision: ['symbol()', 'link_classic_internal(uint64,int64)']
# WARNING:binary_extractor.arch.evm.emulator:[X] Loop detected, skipping JUMPI 0x760
# WARNING:binary_extractor.arch.evm.emulator:[X] push_instr.ssa %411 = #0x760
# 0x57ff71ff2a508ddc8016f22d27e0a02fef9c0f88.sol.txt is done!
# 0x57ff71ff2a508ddc8016f22d27e0a02fef9c0f88.sol
# 0xc5651f5b3008ef0415c8eee6d9604adf6d197fbd.sol.txt
# WARNING:binary_extractor.arch.evm.cfg:function signatures collision: ['ideal_warn_timed(uint256,uint128)', 'owner()']
# 0xc5651f5b3008ef0415c8eee6d9604adf6d197fbd.sol.txt is done!
# 0xc5651f5b3008ef0415c8eee6d9604adf6d197fbd.sol
# 0xad6b277c72dc0917f2e5a53998c517fbea03a6ef.sol.txt
# WARNING:binary_extractor.arch.evm.cfg:function signatures collision: ['decimals()', 'available_assert_time(uint16,uint64)']
# WARNING:binary_extractor.arch.evm.cfg:function signatures collision: ['collate_propagate_storage(bytes16)', 'burn(uint256)']
# WARNING:binary_extractor.arch.evm.cfg:function signatures collision: ['symbol()', 'link_classic_internal(uint64,int64)']
# WARNING:binary_extractor.arch.evm.emulator:[X] Loop detected, skipping JUMPI 0xcf3
# WARNING:binary_extractor.arch.evm.emulator:[X] push_instr.ssa %3A2 = #0xCF3
# WARNING:binary_extractor.arch.evm.emulator:[X] Loop detected, skipping JUMPI 0x6e7
# WARNING:binary_extractor.arch.evm.emulator:[X] push_instr.ssa %836 = #0x6E7
# 0xad6b277c72dc0917f2e5a53998c517fbea03a6ef.sol.txt is done!
# 0xad6b277c72dc0917f2e5a53998c517fbea03a6ef.sol
# 0x00a4a3e9279678ca1b564bca66396bb5801192da.sol.txt
# 0x00a4a3e9279678ca1b564bca66396bb5801192da.sol.txt is done!
# 0x00a4a3e9279678ca1b564bca66396bb5801192da.sol
# 0x1e83475e240068540ea63c9c89b4cf0a536fa510.sol.txt
# WARNING:binary_extractor.arch.evm.cfg:function signatures collision: ['ideal_warn_timed(uint256,uint128)', 'owner()']
# 0x1e83475e240068540ea63c9c89b4cf0a536fa510.sol.txt is done!
# 0x1e83475e240068540ea63c9c89b4cf0a536fa510.sol
# 0x65bf93f65961ff6b778d6b7e52c5807a97c2e4f3.sol.txt
# 0x65bf93f65961ff6b778d6b7e52c5807a97c2e4f3.sol.txt is done!
# 0x65bf93f65961ff6b778d6b7e52c5807a97c2e4f3.sol
# 0x4927643162fe6d18c7f046b3d155d8da0eee80e8.sol.txt
# 0x4927643162fe6d18c7f046b3d155d8da0eee80e8.sol.txt is done!
# 0x4927643162fe6d18c7f046b3d155d8da0eee80e8.sol
# 0xd4cffeef10f60eca581b5e1146b5aca4194a4c3b.sol.txt
# WARNING:binary_extractor.arch.evm.cfg:function signatures collision: ['collate_propagate_storage(bytes16)', 'burn(uint256)']
# 0xd4cffeef10f60eca581b5e1146b5aca4194a4c3b.sol.txt is done!
# 0xd4cffeef10f60eca581b5e1146b5aca4194a4c3b.sol
# 0xf1b767a3e40e33d4c11d83d18ac91f52842853ff.sol.txt
# 0xf1b767a3e40e33d4c11d83d18ac91f52842853ff.sol.txt is done!
# 0xf1b767a3e40e33d4c11d83d18ac91f52842853ff.sol
# 0x5b4e0b60f6f3725628d831057c8a624422b2e9af.sol.txt
# WARNING:binary_extractor.arch.evm.cfg:function signatures collision: ['decimals()', 'available_assert_time(uint16,uint64)']
# WARNING:binary_extractor.arch.evm.cfg:function signatures collision: ['ideal_warn_timed(uint256,uint128)', 'owner()']
# WARNING:binary_extractor.arch.evm.cfg:function signatures collision: ['symbol()', 'link_classic_internal(uint64,int64)']
# 0x5b4e0b60f6f3725628d831057c8a624422b2e9af.sol.txt is done!
# 0x5b4e0b60f6f3725628d831057c8a624422b2e9af.sol
# 0x744c9c36d1cc3268a4b9b2e28c60b1752c85e97d.sol.txt
# WARNING:binary_extractor.arch.evm.cfg:function signatures collision: ['ideal_warn_timed(uint256,uint128)', 'owner()']
# 0x744c9c36d1cc3268a4b9b2e28c60b1752c85e97d.sol.txt is done!
# 0x744c9c36d1cc3268a4b9b2e28c60b1752c85e97d.sol
# 0x6608c25a12ee41bebbe72eb3a7f936fb440493b6.sol.txt
# WARNING:binary_extractor.arch.evm.cfg:function signatures collision: ['ideal_warn_timed(uint256,uint128)', 'owner()']
# 0x6608c25a12ee41bebbe72eb3a7f936fb440493b6.sol.txt is done!
# 0x6608c25a12ee41bebbe72eb3a7f936fb440493b6.sol
# 0x09e44bc655da8300a78e144aee31b065c445fd48.sol.txt
# WARNING:binary_extractor.arch.evm.cfg:function signatures collision: ['ideal_warn_timed(uint256,uint128)', 'owner()']
# 0x09e44bc655da8300a78e144aee31b065c445fd48.sol.txt is done!
# 0x09e44bc655da8300a78e144aee31b065c445fd48.sol
# 0xeb26faf62c78df4b2516af8343699b0bd5738458.sol.txt
# WARNING:binary_extractor.arch.evm.cfg:function signatures collision: ['ideal_warn_timed(uint256,uint128)', 'owner()']
# 0xeb26faf62c78df4b2516af8343699b0bd5738458.sol.txt is done!
# 0xeb26faf62c78df4b2516af8343699b0bd5738458.sol
# 0xfaed077b92cecf624f134ed8d03652c9a9608a58.sol.txt
# 0xfaed077b92cecf624f134ed8d03652c9a9608a58.sol.txt is done!
# 0xfaed077b92cecf624f134ed8d03652c9a9608a58.sol
# 0x4a89cd486fa996ad50c0a63c35c78702f5422a50.sol.txt
# WARNING:binary_extractor.arch.evm.cfg:function signatures collision: ['collate_propagate_storage(bytes16)', 'burn(uint256)']
# 0x4a89cd486fa996ad50c0a63c35c78702f5422a50.sol.txt is done!
# 0x4a89cd486fa996ad50c0a63c35c78702f5422a50.sol
# 0xe6b46cb05644e930862b8d4ed86260522a4ce3b9.sol.txt
# WARNING:binary_extractor.arch.evm.cfg:function signatures collision: ['symbol()', 'link_classic_internal(uint64,int64)']
# 0xe6b46cb05644e930862b8d4ed86260522a4ce3b9.sol.txt is done!
# 0xe6b46cb05644e930862b8d4ed86260522a4ce3b9.sol
# 0x6704e83fac5fc347efbdba61728e62389ab54367.sol.txt
# 0x6704e83fac5fc347efbdba61728e62389ab54367.sol.txt is done!
# 0x6704e83fac5fc347efbdba61728e62389ab54367.sol
# 0xc5c02655bbd508545b4e32ec88cef3aa5e741d87.sol.txt
# 0xc5c02655bbd508545b4e32ec88cef3aa5e741d87.sol.txt is done!
# 0xc5c02655bbd508545b4e32ec88cef3aa5e741d87.sol
# 0x0411b4652f6087d02f633119043e6199841e37eb.sol.txt
# WARNING:binary_extractor.arch.evm.cfg:function signatures collision: ['decimals()', 'available_assert_time(uint16,uint64)']
# WARNING:binary_extractor.arch.evm.cfg:function signatures collision: ['symbol()', 'link_classic_internal(uint64,int64)']
# 0x0411b4652f6087d02f633119043e6199841e37eb.sol.txt is done!
# 0x0411b4652f6087d02f633119043e6199841e37eb.sol
# 0x518d3f4aa7c544079e06f5930b0cbb24a8e762a1.sol.txt
# 0x518d3f4aa7c544079e06f5930b0cbb24a8e762a1.sol.txt is done!
# 0x518d3f4aa7c544079e06f5930b0cbb24a8e762a1.sol
# 0x850a0e200ba62474908801a8e25e6935c14a2c83.sol.txt
# WARNING:binary_extractor.arch.evm.cfg:function signatures collision: ['collate_propagate_storage(bytes16)', 'burn(uint256)']
# WARNING:binary_extractor.arch.evm.cfg:function signatures collision: ['ideal_warn_timed(uint256,uint128)', 'owner()']
# 0x850a0e200ba62474908801a8e25e6935c14a2c83.sol.txt is done!
# 0x850a0e200ba62474908801a8e25e6935c14a2c83.sol
# 0x4065868b974dab5d047023547d3874c6b2e469a3.sol.txt
# WARNING:binary_extractor.arch.evm.cfg:function signatures collision: ['decimals()', 'available_assert_time(uint16,uint64)']
# WARNING:binary_extractor.arch.evm.cfg:function signatures collision: ['collate_propagate_storage(bytes16)', 'burn(uint256)']
# WARNING:binary_extractor.arch.evm.cfg:function signatures collision: ['ideal_warn_timed(uint256,uint128)', 'owner()']
# WARNING:binary_extractor.arch.evm.cfg:function signatures collision: ['symbol()', 'link_classic_internal(uint64,int64)']
# WARNING:binary_extractor.arch.evm.emulator:[X] Loop detected, skipping JUMPI 0x1537
# WARNING:binary_extractor.arch.evm.emulator:[X] push_instr.ssa %326 = #0x1537
# WARNING:binary_extractor.arch.evm.emulator:[X] Loop detected, skipping JUMPI 0x8c7
# WARNING:binary_extractor.arch.evm.emulator:[X] push_instr.ssa %967 = #0x8C7
# 0x4065868b974dab5d047023547d3874c6b2e469a3.sol.txt is done!
# 0x4065868b974dab5d047023547d3874c6b2e469a3.sol
# []
