# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/NCKH_Trinh_Kien_Hoang/Kien/CFG_SCKGNN_Detect
# Out:
# /content/drive/MyDrive/NCKH_Trinh_Kien_Hoang/Kien/CFG_SCKGNN_Detect

# %%
# !sudo update-alternatives --install /usr/bin/python3 python3 /usr/bin/python3.8 1

# %%
# !sudo update-alternatives --config python3
# Out:
# There are 2 choices for the alternative python3 (providing /usr/bin/python3).
#
#   Selection    Path                 Priority   Status
# ------------------------------------------------------------
# * 0            /usr/bin/python3.10   2         auto mode
#   1            /usr/bin/python3.10   2         manual mode
#   2            /usr/bin/python3.8    1         manual mode
#
# Press <enter> to keep the current choice[*], or type selection number: 2
# update-alternatives: using /usr/bin/python3.8 to provide /usr/bin/python3 (python3) in manual mode

# %%
# !apt-get install python3-pip
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   python-pip-whl python3-setuptools python3-wheel
# Suggested packages:
#   python-setuptools-doc
# The following NEW packages will be installed:
#   python-pip-whl python3-pip python3-setuptools python3-wheel
# 0 upgraded, 4 newly installed, 0 to remove and 13 not upgraded.
# Need to get 2,389 kB of archives.
# After this operation, 4,933 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 python-pip-whl all 20.0.2-5ubuntu1.9 [1,805 kB]
# Get:2 http://archive.ubuntu.com/ubuntu focal-updates/main amd64 python3-setuptools all 45.2.0-1ubuntu0.1 [330 kB]
# Get:3 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 python3-wheel all 0.34.2-1ubuntu0.1 [23.9 kB]
# Get:4 http://archive.ubuntu.com/ubuntu focal-updates/universe amd64 python3-pip all 20.0.2-5ubuntu1.9 [231 kB]
# ...

# %%
# !pip -V
# Out:
# pip 20.0.2 from /usr/lib/python3/dist-packages/pip (python 3.8)

# %%
# !pip install openai
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 73 kB 892 kB/s
# ...
#      |████████████████████████████████| 1.0 MB 23.0 MB/s
# ...
#      |████████████████████████████████| 62 kB 957 kB/s
# ...
#      |████████████████████████████████| 77 kB 4.7 MB/s
# ...
#      |████████████████████████████████| 121 kB 66.0 MB/s
# ...
#      |████████████████████████████████| 161 kB 63.3 MB/s
# ...
#      |████████████████████████████████| 266 kB 61.9 MB/s
# ...
#      |████████████████████████████████| 61 kB 7.3 MB/s
# ...
#      |████████████████████████████████| 195 kB 64.1 MB/s
# ...
#      |████████████████████████████████| 123 kB 56.9 MB/s
# ...
#      |████████████████████████████████| 61 kB 94 kB/s
# ...
#      |████████████████████████████████| 156 kB 22.2 MB/s
# ...

# %%
# !pip install scikit-learn scipy pandas plotly matplotlib
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 9.8 MB 4.0 MB/s
# ...
#      |████████████████████████████████| 34.5 MB 18 kB/s
# ...
#      |████████████████████████████████| 12.3 MB 48.8 MB/s
# ...
#      |████████████████████████████████| 15.5 MB 38.6 MB/s
# ...
#      |████████████████████████████████| 9.2 MB 181 kB/s
# ...
#      |████████████████████████████████| 17.3 MB 61.5 MB/s
# ...
#      |████████████████████████████████| 297 kB 52.9 MB/s
# ...
#      |████████████████████████████████| 502 kB 61.9 MB/s
# ...
#      |████████████████████████████████| 341 kB 65.6 MB/s
# ...
#      |████████████████████████████████| 247 kB 67.3 MB/s
# ...
#      |████████████████████████████████| 48 kB 5.2 MB/s
# ...
#      |████████████████████████████████| 4.4 MB 73.1 MB/s
# ...
#      |████████████████████████████████| 1.2 MB 73.4 MB/s
# ...
#      |████████████████████████████████| 300 kB 73.7 MB/s
# ...
#      |████████████████████████████████| 102 kB 78.5 MB/s
# ...

# %%
# !pip install tenacity
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !pip install jax
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 1.3 MB 3.9 MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#      |████████████████████████████████| 65 kB 3.2 MB/s
# ...
#      |████████████████████████████████| 1.0 MB 40.8 MB/s
# ...
#   Created wheel for jax: filename=jax-0.4.13-py3-none-any.whl size=1518707 sha256=5517b1ea8d59d3efcb7889091a254af9169bae7fba1276603417b1af4e0b0997
#   Stored in directory: /root/.cache/pip/wheels/46/d9/15/d2800d4089dc4c77299ac7513c6aa1036f5491edbd2bf6ba16
# Successfully built jax
# ...

# %%
# !pip install jaxlib
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 71.6 MB 36 kB/s
# ...

# %%
# !pip install jraph
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 90 kB 2.8 MB/s
# ...

# %%
# !cp -R /content/drive/MyDrive/NCKH_Trinh_Kien_Hoang/Kien/CFG_SCKGNN_Detect/binary_extractor /content

# %%
# !cp -R /content/drive/MyDrive/NCKH_Trinh_Kien_Hoang/Kien/CFG_SCKGNN_Detect/bgraph_to_jraph.py /content

# %%
# %cd /content
# Out:
# /content

# %% [markdown]
# # Test Reentrancy
# 1Cofmhhgm5R2sVX54bz8T3BlbkFJHi0jrv1OD0SUO5QQqwaq

# %%
# !python3 bgraph_to_jraph.py
# Out:
# 591 591
# 591
# 591
# Total # of graphs 591
# Processing graph 0
# Processing graph 1
# Waiting for 65
# Waiting for 53
# Processing graph 2
# Waiting for 51
# Processing graph 3
# Processing graph 4
# Waiting for 49
# Processing graph 5
# Processing graph 6
# Processing graph 7
# Processing graph 8
# Waiting for 49
# Processing graph 9
# Processing graph 10
# Processing graph 11
# Processing graph 12
# Processing graph 13
# Processing graph 14
# Processing graph 15
# Processing graph 16
# Processing graph 17
# Processing graph 18
# Processing graph 19
# Processing graph 20
# Processing graph 21
# Waiting for 51
# Processing graph 22
# Processing graph 23
# Processing graph 24
# Processing graph 25
# Processing graph 26
# Waiting for 51
# Processing graph 27
# Processing graph 28
# Processing graph 29
# Processing graph 30
# Processing graph 31
# Processing graph 32
# Processing graph 33
# Processing graph 34
# Processing graph 35
# Processing graph 36
# Processing graph 37
# ...

# %%
# !cp -R /content/drive/MyDrive/NCKH_Trinh_Kien_Hoang/Kien/CFG_SCKGNN_Detect/create_jraph_dataset.py /content

# %%
# !python3 create_jraph_dataset.py
# Out:
# 591
# {'input_graph': GraphsTuple(nodes=array([[-0.01170208, -0.00597553, -0.01321615, ...,  0.01059176,
#          0.00572992, -0.03238092],
#        [-0.01488919, -0.01571399, -0.02110368, ...,  0.0126423 ,
#          0.00110211, -0.03430059]]), edges=array([], dtype=float64), receivers=array([], dtype=float64), senders=array([], dtype=float64), globals=array([1]), n_node=array([2]), n_edge=array([0])), 'name': '0x018429f6c919847217b05f6073991bc7cf00c6f7.txt'}
# GraphsTuple(nodes=array([[-0.01170208, -0.00597553, -0.01321615, ...,  0.01059176,
#          0.00572992, -0.03238092],
#        [-0.01488919, -0.01571399, -0.02110368, ...,  0.0126423 ,
#          0.00110211, -0.03430059]]), edges=array([], dtype=float64), receivers=array([], dtype=float64), senders=array([], dtype=float64), globals=array([1]), n_node=array([2]), n_edge=array([0]))

# %%
# !python3 bgraph_to_jraph.py
# Out:
# 548 548
# 548
# 548
# Total # of graphs 548
# Processing graph 278
# Waiting for 12
# Waiting for 47
# Waiting for 47
# Processing graph 279
# Waiting for 46
# Waiting for 47
# Processing graph 280
# Processing graph 281
# Waiting for 47
# Processing graph 282
# Waiting for 48
# Waiting for 46
# Waiting for 48
# Waiting for 48
# Processing graph 283
# Processing graph 284
# Waiting for 45
# Waiting for 48
# Waiting for 48
# Processing graph 286
# Waiting for 48
# Processing graph 287
# Processing graph 288
# Processing graph 289
# Waiting for 47
# Waiting for 44
# Processing graph 291
# Processing graph 292
# Waiting for 47
# Waiting for 47
# Waiting for 45
# Processing graph 293
# Waiting for 47
# Waiting for 47
# Waiting for 46
# Processing graph 294
# Waiting for 42
# Waiting for 45
# Processing graph 295
# Waiting for 42
# Waiting for 47
# Processing graph 296
# Waiting for 47
# Waiting for 47
# Waiting for 46
# Processing graph 298
# Processing graph 299
# Waiting for 48
# ...
